# %%
# conda install keras
! conda install tensorflow
# Out:
# ==> WARNING: A newer version of conda exists. <==
#   current version: 23.5.2
#   latest version: 23.7.2
#
# Please update conda by running
#
#     $ conda update -n base -c defaults conda
#
# Or to minimize the number of packages updated during conda update use
#
#      conda install conda=23.7.2
# Collecting package metadata (current_repodata.json): ...working... done
# Solving environment: ...working... done
#
# # All requested packages already installed.

# %%
conda install conda=23.7.2
# Out:
# Collecting package metadata (current_repodata.json): ...working... done
# Note: you may need to restart the kernel to use updated packages.
#
# Solving environment: ...working... unsuccessful initial attempt using frozen solve. Retrying with flexible solve.
# Solving environment: ...working... unsuccessful attempt using repodata from current_repodata.json, retrying with next repodata source.
# Collecting package metadata (repodata.json): ...working... done
# Solving environment: ...working... done
#
# ## Package Plan ##
#
#   environment location: c:\Users\siriw\miniconda3\envs\myenv
#
#   added / updated specs:
#     - conda=23.7.2
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     boltons-23.0.0             |  py310haa95532_0         425 KB
#     conda-23.7.2               |  py310haa95532_0         1.0 MB
#     conda-package-handling-2.2.0|  py310haa95532_0         287 KB
#     conda-package-streaming-0.9.0|  py310haa95532_0          29 KB
#     menuinst-1.4.19            |  py310h59b6b97_0          94 KB
#     pluggy-1.0.0               |  py310haa95532_1          29 KB
#     pycosat-0.6.4              |  py310h2bbff1b_0          75 KB
#     ruamel.yaml-0.17.21        |  py310h2bbff1b_0         177 KB
#     ruamel.yaml.clib-0.2.6     |  py310h2bbff1b_1         101 KB
#     toolz-0.12.0               |  py310haa95532_0         108 KB
#     tqdm-4.65.0                |  py310h9909e9c_0         149 KB
#     zstandard-0.19.0           |  py310h2bbff1b_0         340 KB
#     ------------------------------------------------------------
#                                            Total:         2.8 MB
#
# The following NEW packages will be INSTALLED:
#
#   boltons            pkgs/main/win-64::boltons-23.0.0-py310haa95532_0
#   conda              pkgs/main/win-64::conda-23.7.2-py310haa95532_0
#   conda-package-han~ pkgs/main/win-64::conda-package-handling-2.2.0-py310haa95532_0
#   conda-package-str~ pkgs/main/win-64::conda-package-streaming-0.9.0-py310haa95532_0
#   jsonpatch          pkgs/main/noarch::jsonpatch-1.32-pyhd3eb1b0_0
#   jsonpointer        pkgs/main/noarch::jsonpointer-2.1-pyhd3eb1b0_0
#   menuinst           pkgs/main/win-64::menuinst-1.4.19-py310h59b6b97_0
#   pluggy             pkgs/main/win-64::pluggy-1.0.0-py310haa95532_1
#   pycosat            pkgs/main/win-64::pycosat-0.6.4-py310h2bbff1b_0
#   ruamel.yaml        pkgs/main/win-64::ruamel.yaml-0.17.21-py310h2bbff1b_0
#   ruamel.yaml.clib   pkgs/main/win-64::ruamel.yaml.clib-0.2.6-py310h2bbff1b_1
#   toolz              pkgs/main/win-64::toolz-0.12.0-py310haa95532_0
#   tqdm               pkgs/main/win-64::tqdm-4.65.0-py310h9909e9c_0
#   zstandard          pkgs/main/win-64::zstandard-0.19.0-py310h2bbff1b_0
#
#
#
# Downloading and Extracting Packages
#
# ruamel.yaml.clib-0.2 | 101 KB    |            |   0%
#
# toolz-0.12.0         | 108 KB    |            |   0%
#
#
# ruamel.yaml-0.17.21  | 177 KB    |            |   0%
#
#
#
# pluggy-1.0.0         | 29 KB     |            |   0%
#
#
#
#
# boltons-23.0.0       | 425 KB    |            |   0%
#
#
#
#
#
# menuinst-1.4.19      | 94 KB     |            |   0%
#
#
#
#
#
#
# tqdm-4.65.0          | 149 KB    |            |   0%
#
#
#
#
#
#
#
# zstandard-0.19.0     | 340 KB    |            |   0%
#
#
#
#
#
#
#
#
# conda-package-handli | 287 KB    |            |   0%
#
#
#
#
#
#
#
#
#
# conda-23.7.2         | 1.0 MB    |            |   0%
#
#
#
#
#
#
#
#
#
#
# conda-package-stream | 29 KB     |            |   0%
#
#
#
#
#
#
#
#
#
#
#
# pycosat-0.6.4        | 75 KB     |            |   0%
#
#
#
# pluggy-1.0.0         | 29 KB     | #####4     |  55%
#
# toolz-0.12.0         | 108 KB    | #4         |  15%
#
#
#
#
# boltons-23.0.0       | 425 KB    | 3          |   4%
#
#
#
# pluggy-1.0.0         | 29 KB     | ########## | 100%
#
#
#
#
# boltons-23.0.0       | 425 KB    | #1         |  11%
#
# toolz-0.12.0         | 108 KB    | #######3   |  74%
#
#
#
#
# boltons-23.0.0       | 425 KB    | ##2        |  23%
#
# toolz-0.12.0         | 108 KB    | ########## | 100%
#
#
# ruamel.yaml-0.17.21  | 177 KB    | 9          |   9%
#
#
#
#
# boltons-23.0.0       | 425 KB    | ###        |  30%
#
#
# ruamel.yaml-0.17.21  | 177 KB    | ##7        |  27%
#
#
# ruamel.yaml-0.17.21  | 177 KB    | ######3    |  63%
# ruamel.yaml.clib-0.2 | 101 KB    | #5         |  16%
#
#
# ruamel.yaml-0.17.21  | 177 KB    | ########1  |  82%
#
#
#
#
#
#
# tqdm-4.65.0          | 149 KB    | #          |  11%
#
#
#
#
#
#
# tqdm-4.65.0          | 149 KB    | ####2      |  43%
# ruamel.yaml.clib-0.2 | 101 KB    | ####7      |  48%
#
#
# ruamel.yaml-0.17.21  | 177 KB    | #########9 | 100%
#
#
#
#
#
#
# tqdm-4.65.0          | 149 KB    | ######4    |  64%
#
#
# ruamel.yaml-0.17.21  | 177 KB    | ########## | 100%
#
#
#
#
#
# menuinst-1.4.19      | 94 KB     | #6         |  17%
#
#
#
#
#
#
# tqdm-4.65.0          | 149 KB    | #########6 |  96%
# ruamel.yaml.clib-0.2 | 101 KB    | #########5 |  95%
#
#
#
#
# boltons-23.0.0       | 425 KB    | ###7       |  38%
# ruamel.yaml.clib-0.2 | 101 KB    | ########## | 100%
#
#
#
#
#
#
# tqdm-4.65.0          | 149 KB    | ########## | 100%
#
#
#
#
#
# menuinst-1.4.19      | 94 KB     | ######7    |  68%
#
#
#
#
# boltons-23.0.0       | 425 KB    | ####8      |  49%
#
#
#
#
#
# menuinst-1.4.19      | 94 KB     | ########## | 100%
#
#
#
#
#
#
#
# zstandard-0.19.0     | 340 KB    | 4          |   5%
#
#
#
#
#
#
#
#
#
# conda-23.7.2         | 1.0 MB    | 1          |   2%
#
#
#
#
#
#
#
#
# conda-package-handli | 287 KB    | 5          |   6%
#
#
#
#
# boltons-23.0.0       | 425 KB    | ######     |  60%
#
#
#
#
#
#
#
#
#
#
# conda-package-stream | 29 KB     | #####4     |  55%
#
#
#
#
#
#
#
#
#
#
# conda-package-stream | 29 KB     | ########## | 100%
#
#
#
#
#
#
#
#
#
# conda-23.7.2         | 1.0 MB    | 4          |   5%
#
#
#
#
#
#
#
#
# conda-package-handli | 287 KB    | ##7        |  28%
#
#
#
#
#
#
#
# zstandard-0.19.0     | 340 KB    | 9          |   9%
#
#
#
#
#
#
#
#
# conda-package-handli | 287 KB    | ###8       |  39%
#
#
#
#
# boltons-23.0.0       | 425 KB    | #######1   |  72%
#
#
#
#
#
#
#
#
#
# conda-23.7.2         | 1.0 MB    | 9          |   9%
#
#
#
#
#
#
#
#
# conda-package-handli | 287 KB    | #####5     |  56%
#
#
#
#
#
#
#
# zstandard-0.19.0     | 340 KB    | ##3        |  24%
#
#
#
#
#
#
#
#
#
# conda-23.7.2         | 1.0 MB    | #2         |  12%
#
#
#
#
#
#
#
#
# conda-package-handli | 287 KB    | ######6    |  67%
#
#
#
#
# boltons-23.0.0       | 425 KB    | ########2  |  83%
#
#
#
#
#
#
#
#
#
#
#
# pycosat-0.6.4        | 75 KB     | ##1        |  21%
#
#
#
#
#
#
#
#
# conda-package-handli | 287 KB    | ########3  |  84%
#
#
#
#
# boltons-23.0.0       | 425 KB    | #########  |  90%
#
#
#
#
#
#
#
#
# conda-package-handli | 287 KB    | #########4 |  95%
#
#
#
#
#
#
#
# zstandard-0.19.0     | 340 KB    | ###7       |  38%
#
#
#
#
#
#
#
#
#
# conda-23.7.2         | 1.0 MB    | #5         |  15%
#
#
#
#
#
#
#
#
# conda-package-handli | 287 KB    | ########## | 100%
#
#
#
#
# boltons-23.0.0       | 425 KB    | ########## | 100%
#
#
#
#
# boltons-23.0.0       | 425 KB    | ########## | 100%
#
#
#
#
#
#
#
#
#
#
#
# pycosat-0.6.4        | 75 KB     | ########5  |  86%
#
#
#
#
#
#
#
#
#
#
#
# pycosat-0.6.4        | 75 KB     | ########## | 100%
#
#
#
#
#
#
#
# zstandard-0.19.0     | 340 KB    | #####1     |  52%
#
#
#
#
#
#
#
#
#
# conda-23.7.2         | 1.0 MB    | #8         |  19%
#
#
#
#
#
#
#
# zstandard-0.19.0     | 340 KB    | ######5    |  66%
#
#
#
#
#
#
#
#
#
# conda-23.7.2         | 1.0 MB    | ##3        |  23%
#
#
#
#
#
#
#
# zstandard-0.19.0     | 340 KB    | ########   |  80%
#
#
#
#
#
#
#
#
#
# conda-23.7.2         | 1.0 MB    | ##7        |  28%
#
#
#
#
#
#
#
# zstandard-0.19.0     | 340 KB    | #########4 |  94%
#
#
#
#
#
#
#
#
#
# conda-23.7.2         | 1.0 MB    | ###2       |  32%
#
#
#
#
#
#
#
# zstandard-0.19.0     | 340 KB    | ########## | 100%
#
#
#
#
#
#
#
#
#
# conda-23.7.2         | 1.0 MB    | ###7       |  37%
#
#
#
#
#
#
#
#
#
# conda-23.7.2         | 1.0 MB    | ####3      |  43%
#
#
#
#
#
#
#
#
#
# conda-23.7.2         | 1.0 MB    | ####7      |  48%
#
#
#
#
#
#
#
#
#
# conda-23.7.2         | 1.0 MB    | #####2     |  53%
#
#
#
#
#
#
#
#
#
# conda-23.7.2         | 1.0 MB    | #####8     |  59%
#
#
#
#
#
#
#
#
#
# conda-23.7.2         | 1.0 MB    | ######3    |  63%
#
#
#
#
#
#
#
#
#
# conda-23.7.2         | 1.0 MB    | ######7    |  68%
#
#
#
#
#
#
#
#
#
# conda-23.7.2         | 1.0 MB    | #######4   |  74%
#
#
#
#
#
#
#
#
#
# conda-23.7.2         | 1.0 MB    | ########   |  80%
#
#
#
#
#
#
#
#
#
# conda-23.7.2         | 1.0 MB    | ########6  |  87%
#
#
#
#
#
#
#
#
#
# conda-23.7.2         | 1.0 MB    | #########2 |  93%
#
#
#
#
#
#
#
#
#
# conda-23.7.2         | 1.0 MB    | #########8 |  99%
#
#
#
#
#
#
#
#
#
# conda-23.7.2         | 1.0 MB    | ########## | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Preparing transaction: ...working... done
# Verifying transaction: ...working... done
# Executing transaction: ...working... done
# ==> WARNING: A newer version of conda exists. <==
#   current version: 23.5.2
#   latest version: 23.7.2
#
# Please update conda by running
#
#     $ conda update -n base -c defaults conda
#
# Or to minimize the number of packages updated during conda update use
#
#      conda install conda=23.7.2

# %%
from keras.datasets import mnist
import numpy as np
import matplotlib.pyplot as plt

# %%
data = mnist.load_data()
(x_train, y_train), (x_test, y_test) = data

# %%
# x_train.shape
plt.imshow(x_train[0] , cmap = 'gray')
plt.title(y_train[0])
plt.show()

# %% [markdown]
# # create modle

# %%
# from keras.models import Sequential
from keras.layers import Dense, Dropout, Flatten, Conv2D, MaxPooling2D
from tensorflow.keras.models import Sequential

# %%
model= Sequential()
# Out:
# Cannot execute code, session has been disposed. Please try restarting the Kernel.
# The Kernel crashed while executing code in the the current cell or a previous cell. Please review the code in the cell(s) to identify a possible cause of the failure. Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info. View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
